# %% [markdown]
# # Tuberculosis Classification via X-Rays CNN 1

# %% [markdown]
# # Final Framework
#
# 1. Importing all necessary functions
#
# 2. Dataset
#   - Defining variables
#   - Importing dataset
#   - Visualising dataset
#   - Prefetching dataset
#
# 3. Model
#   - Defining model
#   - Initialising model
#   - Training and validating model
#
# 4. Reporting results

# %% [markdown]
# # 1. Importing all necessary functions

# %%
# to mount google drive

from google.colab.drive import mount

# to generate dataset

from tensorflow.keras.preprocessing import image_dataset_from_directory

# to augment dataset

from tensorflow.keras import Sequential
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip

# to visualize dataset

import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# to build model

from tensorflow.keras import Input
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras import Model

# to view model

from tensorflow.keras.utils import plot_model

# to define callbacks

from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

# to compile model

from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # 2. Dataset
#
# Defining variables

# %%
image_size = (256, 256)
batch_size = 32
epochs = 100

# %% [markdown]
# Importing dataset

# %%
# mounting drive

mount('/content/drive')

# creating training and validation data

train_ds = image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/x_ray_tb/data/train" ,
    validation_split = 0.2 ,
    subset = "training",
    seed = 1337,
    image_size = image_size ,
    batch_size = batch_size ,
    color_mode = 'grayscale'    
)

val_ds = image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/x_ray_tb/data/train" ,
    validation_split = 0.2 ,
    subset = "validation",
    seed = 1337,
    image_size = image_size ,
    batch_size = batch_size ,
    color_mode = 'grayscale'   
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 718 files belonging to 2 classes.
# Using 575 files for training.
# Found 718 files belonging to 2 classes.
# Using 143 files for validation.

# %% [markdown]
# Visualising dataset

# %%
# Load an color image in grayscale

img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/x_ray_tb/data/train/normal/AISHOPWY.png',0)
print('Normal')
cv2_imshow(cv2.resize(img, image_size))

img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/x_ray_tb/data/train/tb/AANPRUIV.png',0)
print('Tuberculosis')
cv2_imshow(cv2.resize(img, image_size))
# Out:
# Normal
# <PIL.Image.Image image mode=L size=256x256 at 0x7F824C6167B8>
# Tuberculosis
# <PIL.Image.Image image mode=L size=256x256 at 0x7F824C616780>

# %% [markdown]
# Prefetching dataset

# %%
train_ds = train_ds.prefetch(buffer_size = batch_size)
val_ds = val_ds.prefetch(buffer_size = batch_size)

# %% [markdown]
# # 3. Model
#
# Defining model

# %%
# function to make model

def make_model(input_shape):
    
    inputs = Input(shape = input_shape)
    x = Rescaling(1.0 / 255)(inputs)

    # first conv block
    
    x = Conv2D(
        filters=32, 
        kernel_size=3, 
        padding='same'
        )(x)

    x = Activation("relu")(x)
    x = MaxPool2D()(x)

    # second conv block

    x = Conv2D(
        filters=64, 
        kernel_size=5, 
        padding='same'
        )(x)

    x = Activation("relu")(x)
    x = MaxPool2D()(x)

    # third conv block

    x = Conv2D(
        filters=128, 
        kernel_size=7, 
        padding='same'
        )(x)

    x = Activation("relu")(x)
    x = MaxPool2D()(x)

    # fully connected layer

    x = Flatten()(x)
    x = Dropout(rate=0.5)(x)
    x = Dense(
        units=256, 
        activation='relu'
        )(x)

    outputs = Dense(
        units=1, 
        activation = "sigmoid"
        )(x)
        
    return Model(inputs, outputs)

# %% [markdown]
# Initialising model

# %%
# making a model

model = make_model(input_shape = image_size + (1,))

# viewing model

plot_model(
    model, 
    show_shapes = True
    )

# %% [markdown]
# Training and validating model

# %%
# setting callbacks

callbacks = [
             ReduceLROnPlateau(
                 monitor='val_loss', 
                 factor=0.2, 
                 patience=5, 
                 mode='max', 
                 verbose=1
                 ),
             EarlyStopping(
                 monitor='val_loss', 
                 min_delta=0.01, 
                 patience=5,
                 mode='min', 
                 verbose=1
                 )
             ]

# compiling model

model.compile(
    optimizer = Adam(1e-3),
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
    )

# training and validating

model.fit(
    train_ds, 
    epochs=epochs, 
    callbacks=callbacks, 
    validation_data=val_ds
    )
# Out:
# Epoch 1/100
# 18/18 [==============================] - 280s 16s/step - loss: 1.8057 - accuracy: 0.5791 - val_loss: 0.6768 - val_accuracy: 0.6014
# Epoch 2/100
# 18/18 [==============================] - 81s 4s/step - loss: 0.6293 - accuracy: 0.6800 - val_loss: 0.6161 - val_accuracy: 0.6364
# Epoch 3/100
# 18/18 [==============================] - 81s 4s/step - loss: 0.5234 - accuracy: 0.7583 - val_loss: 0.4205 - val_accuracy: 0.7622
# Epoch 4/100
# 18/18 [==============================] - 82s 5s/step - loss: 0.4641 - accuracy: 0.7948 - val_loss: 0.5271 - val_accuracy: 0.7622
# Epoch 5/100
# 18/18 [==============================] - 81s 4s/step - loss: 0.4308 - accuracy: 0.8070 - val_loss: 0.4011 - val_accuracy: 0.8112
# Epoch 6/100
# 18/18 [==============================] - ETA: 0s - loss: 0.3567 - accuracy: 0.8452
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 18/18 [==============================] - 81s 5s/step - loss: 0.3567 - accuracy: 0.8452 - val_loss: 0.3860 - val_accuracy: 0.8322
# Epoch 7/100
# 18/18 [==============================] - 81s 4s/step - loss: 0.3111 - accuracy: 0.8800 - val_loss: 0.3929 - val_accuracy: 0.8322
# Epoch 8/100
# 18/18 [==============================] - 81s 4s/step - loss: 0.2921 - accuracy: 0.8783 - val_loss: 0.3956 - val_accuracy: 0.8322
# Epoch 9/100
# 18/18 [==============================] - 82s 5s/step - loss: 0.2767 - accuracy: 0.8904 - val_loss: 0.4028 - val_accuracy: 0.8252
# Epoch 10/100
# 18/18 [==============================] - 82s 5s/step - loss: 0.2696 - accuracy: 0.8870 - val_loss: 0.4088 - val_accuracy: 0.8252
# Epoch 11/100
# 18/18 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.9061
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 18/18 [==============================] - 82s 5s/step - loss: 0.2458 - accuracy: 0.9061 - val_loss: 0.4122 - val_accuracy: 0.8252
# Epoch 00011: early stopping
